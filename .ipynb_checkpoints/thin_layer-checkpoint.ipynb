# %%
import numpy as np #numpy
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.patches as patches
import matplotlib.font_manager
from IPython.display import display, HTML # my imports
import matplotlib.font_manager


import pandas as pd
import scipy.signal as signal
import ipywidgets as widgets
from ipywidgets import interact

import pims
import cv2 as cv
import skimage as scikit

import trackpy as tp

from pandas_ods_reader import read_ods #read ods tables

import subprocess # these 2 lines below load OS functionality
import sys
import gc 
import json
import warnings

# %matplotlib --list
# %matplotlib inline

plt.rcParams['font.family'] = 'Helvetica'
plt.rcParams.update({'font.size':12})

print('\npandas version no.:', pd.__version__)

# print progress function
# more elegant (python 3 alternative): print('\rhello', end='',flush=True)
def printp(string):
    sys.stdout.write('\r'+ str(string))
    sys.stdout.flush()
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'gtk4', 'wx', 'qt4', 'qt5', 'qt6', 'qt', 'osx', 'nbagg', 'webagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']
#
# pandas version no.: 1.5.1

# %%
# list available fonts 
matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
# Out:
# ['/usr/share/fonts/noto/NotoKufiArabic-Medium.ttf',
#  '/usr/share/fonts/TTF/Webdings.TTF',
#  '/usr/share/fonts/noto/NotoSansCanadianAboriginal-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifHebrew-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-CondensedExtraBold.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-ExtraLightIt.otf',
#  '/usr/share/fonts/gsfonts/URWBookman-DemiItalic.otf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraExpandedExtraBold.ttf',
#  '/usr/share/fonts/noto/NotoKufiArabic-Bold.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-Eight.otf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-Book.otf',
#  '/usr/share/fonts/noto/NotoSansTamil-Light.ttf',
#  '/usr/share/fonts/TTF/trebucbi.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiExpandedMedium.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansCN-Normal.otf',
#  '/usr/share/fonts/noto/NotoSansArabic-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifGujarati-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansChorasmian-Regular.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansKR-Normal.otf',
#  '/usr/share/fonts/droid/DroidSerif-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansMalayalamUI-Regular.ttf',
#  '/usr/share/fonts/TTF/DejaVuSans-Oblique.ttf',
#  '/usr/share/fonts/noto/NotoSerifTamil-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansBengaliUI-Medium.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraCondensed.ttf',
#  '/usr/share/fonts/noto/NotoSerifNyiakengPuachueHmong-Medium.ttf',
#  '/usr/share/fonts/TTF/Verdanaz.TTF',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansCN-ExtraLight.otf',
#  '/usr/share/fonts/noto/NotoSansMono-Thin.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraExpandedMedium.ttf',
#  '/usr/share/fonts/noto/NotoSerifBengali-Light.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-Thin.otf',
#  '/usr/share/fonts/noto/NotoSansSinhalaUI-Medium.ttf',
#  '/usr/share/fonts/TTF/OpenSans-SemiBoldItalic.ttf',
#  '/usr/share/fonts/noto/NotoSansMyanmarUI-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansBengali-Light.ttf',
#  '/usr/share/fonts/TTF/trebuc.ttf',
#  '/usr/share/fonts/noto/NotoSerifTelugu-Thin.ttf',
#  '/usr/share/fonts/gsfonts/NimbusSansNarrow-Oblique.otf',
#  '/usr/share/fonts/noto/NotoSansGurmukhiUI-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansGeorgian-Thin.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansCN-Heavy.otf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-SemiboldIt.otf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-UltLtCnO.otf',
#  '/usr/share/fonts/noto/NotoSerifMyanmar-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifTamilSlanted-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifDevanagari-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-BdEx.otf',
#  '/usr/share/fonts/noto/NotoSerifKannada-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansOriya-Thin.ttf',
#  '/usr/share/fonts/TTF/DejaVuSerif-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansSiddham-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansThai-Black.ttf',
#  '/usr/share/fonts/droid/DroidSerif-BoldItalic.ttf',
#  '/usr/share/fonts/noto/NotoSansLinearA-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansLao-Thin.ttf',
#  '/usr/share/fonts/noto/NotoLoopedLao-Black.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-TwoItalic.otf',
#  '/usr/share/fonts/noto/NotoSansKhmer-Regular.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-LightIt.otf',
#  '/usr/share/fonts/gsfonts/URWBookman-Demi.otf',
#  '/usr/share/fonts/noto/NotoSerif-BoldItalic.ttf',
#  '/usr/share/fonts/gsfonts/P052-BoldItalic.otf',
#  '/usr/share/fonts/noto/NotoSansOldPermic-Regular.ttf',
#  '/usr/share/fonts/noto/NotoNaskhArabicUI-Medium.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-Lt.otf',
#  '/usr/share/fonts/TTF/Inconsolata-ExpandedBlack.ttf',
#  '/usr/share/fonts/noto/NotoKufiArabic-Light.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-BoldIt.otf',
#  '/usr/share/fonts/noto/NotoSerifToto-Bold.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-XBlkCn.otf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-Book.otf',
#  '/usr/share/fonts/noto/NotoSansGurmukhi-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSerifSinhala-Black.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-It.otf',
#  '/usr/share/fonts/noto/NotoSerifDevanagari-Black.ttf',
#  '/usr/share/fonts/droid/DroidSansTamil-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifKhmer-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansThai-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSerifMalayalam-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansHebrewNew-Black.ttf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-ThinItalic.ttf',
#  '/usr/share/fonts/noto/NotoSansSinhala-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansDisplay-BoldItalic.ttf',
#  '/usr/share/fonts/TTF/padmaa-Medium-0.5.ttf',
#  '/usr/share/fonts/noto/NotoSerifArmenian-Regular.ttf',
#  '/usr/share/fonts/liberation/LiberationSerif-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansDevanagariUI-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansKannada-Light.ttf',
#  '/usr/share/fonts/gsfonts/URWGothic-DemiOblique.otf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-BoldItalic.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-BlackIt.otf',
#  '/usr/share/fonts/noto/NotoSansDevanagari-Thin.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-Heavy.otf',
#  '/usr/share/fonts/noto/NotoSerifEthiopic-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-Italic.ttf',
#  '/usr/share/fonts/TTF/FiraCode-SemiBold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraCondensedSemiBold.ttf',
#  '/usr/share/fonts/noto/NotoSansSylotiNagri-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansTifinaghAzawagh-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifToto-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansTamil-Thin.ttf',
#  '/usr/share/fonts/TTF/Verdanab.TTF',
#  '/usr/share/fonts/noto/NotoSerifNyiakengPuachueHmong-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansSinhalaUI-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraExpandedExtraBold.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-Black.otf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-BlackIt.otf',
#  '/usr/share/fonts/noto/NotoSerifGujarati-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansDisplay-Italic.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansKR-Heavy.otf',
#  '/usr/share/fonts/noto/NotoSansLao-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansMyanmarUI-Regular.ttf',
#  '/usr/share/fonts/noto/NotoRashiHebrew-Black.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-Semibold.otf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-LightIt.otf',
#  '/usr/share/fonts/noto/NotoSansMono-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansNKo-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansJavanese-Bold.ttf',
#  '/usr/share/fonts/gsfonts/NimbusSansNarrow-BoldOblique.otf',
#  '/usr/share/fonts/noto/NotoSerif-Italic.ttf',
#  '/usr/share/fonts/TTF/Ligconsolata-Regular.ttf',
#  '/usr/share/fonts/droid/DroidSansGeorgian.ttf',
#  '/usr/share/fonts/noto/NotoSansGujarati-Black.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraCondensedBlack.ttf',
#  '/usr/share/fonts/noto/NotoSansKayahLi-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifGujarati-Bold.ttf',
#  '/usr/share/fonts/OTF/FiraSans-Light.otf',
#  '/usr/share/fonts/noto/NotoLoopedLaoUI-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-MdIt.otf',
#  '/usr/share/fonts/noto/NotoSerifTibetan-Black.ttf',
#  '/usr/share/fonts/noto/NotoNastaliqUrdu-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansAnatolianHieroglyphs-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifGeorgian-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansDuployan-Regular.ttf',
#  '/usr/share/fonts/noto/NotoLoopedLao-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansMedefaidrin-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-ThCnO.otf',
#  '/usr/share/fonts/noto/NotoSerifLao-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansLisu-Regular.ttf',
#  '/usr/share/fonts/droid/DroidSansFallback.ttf',
#  '/usr/share/fonts/noto/NotoSansOldItalic-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-Four.otf',
#  '/usr/share/fonts/noto/NotoSerifGurmukhi-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSerifLao-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-Medium.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-Medium.otf',
#  '/usr/share/fonts/noto/NotoSerifTibetan-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansSymbols-Black.ttf',
#  '/usr/share/fonts/droid/DroidSansThai.ttf',
#  '/usr/share/fonts/noto/NotoSerifKhmer-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansAdlamUnjoined-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansVai-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-CondensedSemiBold.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-BdCnO.otf',
#  '/usr/share/fonts/noto/NotoSansBengali-Regular.ttf',
#  '/usr/share/fonts/droid/DroidSerif-Italic.ttf',
#  '/usr/share/fonts/noto/NotoSansSymbols-Medium.ttf',
#  '/usr/share/fonts/TTF/ani.ttf',
#  '/usr/share/fonts/noto/NotoSans-LightItalic.ttf',
#  '/usr/share/fonts/noto/NotoSansKayahLi-Medium.ttf',
#  '/usr/share/fonts/gsfonts/URWGothic-Demi.otf',
#  '/usr/share/fonts/noto/NotoSansCham-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansTamil-Black.ttf',
#  '/usr/share/fonts/TTF/NotoSansMono-Light-Nerd-Font-Complete.ttf',
#  '/usr/share/fonts/OTF/FiraSans-ExtraLight.otf',
#  '/usr/share/fonts/OTF/FiraSans-ExtraBold.otf',
#  '/usr/share/fonts/noto/NotoSerifDogra-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansLepcha-Regular.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-ExtraLight.otf',
#  '/usr/share/fonts/noto/NotoSansMiao-Regular.ttf',
#  '/usr/share/fonts/TTF/mal2-b.ttf',
#  '/usr/share/fonts/noto/NotoSansTeluguUI-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansMayanNumerals-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerif-MediumItalic.ttf',
#  '/usr/share/fonts/noto/NotoSans-ThinItalic.ttf',
#  '/usr/share/fonts/noto/NotoSansWancho-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSans-Regular.otf',
#  '/usr/share/fonts/noto/NotoLoopedThai-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansArabic-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansMono-Light.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-UltraLight.otf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-UltraLight.otf',
#  '/usr/share/fonts/noto/NotoLoopedThai-Thin.ttf',
#  '/usr/share/fonts/OTF/FiraSans-HairItalic.otf',
#  '/usr/share/fonts/OTF/FiraSans-EightItalic.otf',
#  '/usr/share/fonts/TTF/Trebucbd.ttf',
#  '/usr/share/fonts/noto/NotoSansBassaVah-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansManichaean-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansMyanmarUI-Thin.ttf',
#  '/usr/share/fonts/TTF/NotoSansMono-Medium-Nerd-Font-Complete.ttf',
#  '/usr/share/fonts/noto/NotoSerifHebrew-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansPahawhHmong-Regular.ttf',
#  '/usr/share/fonts/TTF/FiraCode-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansGujarati-Medium.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansJP-Regular.otf',
#  '/usr/share/fonts/noto/NotoLoopedLao-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansThaiUI-Light.ttf',
#  '/usr/share/fonts/TTF/NotoSansMono-Bold-Nerd-Font-Complete.ttf',
#  '/usr/share/fonts/noto/NotoSerifNyiakengPuachueHmong-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansLaoUI-Black.ttf',
#  '/usr/share/fonts/liberation/LiberationMono-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifTangut-Regular.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansVariable-Italic.otf',
#  '/usr/share/fonts/noto/NotoSansSoyombo-Regular.ttf',
#  '/usr/share/fonts/gsfonts/C059-Bold.otf',
#  '/usr/share/fonts/TTF/TAMu_Maduram.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-ThExO.otf',
#  '/usr/share/fonts/OTF/FiraMono-Bold.otf',
#  '/usr/share/fonts/TTF/DejaVuSansMono-BoldOblique.ttf',
#  '/usr/share/fonts/OTF/FiraSans-Eight.otf',
#  '/usr/share/fonts/TTF/MesloLGS-NF-Bold-Italic.ttf',
#  '/usr/share/fonts/noto/NotoSansGurmukhiUI-Black.ttf',
#  '/usr/share/fonts/TTF/Impact.TTF',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-BlkExO.otf',
#  '/usr/share/fonts/noto/NotoSansTamilSupplement-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-LightItalic.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-MdExO.otf',
#  '/usr/share/fonts/gsfonts/URWBookman-Light.otf',
#  '/usr/share/fonts/gsfonts/P052-Italic.otf',
#  '/usr/share/fonts/noto/NotoSansEthiopic-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansDisplay-MediumItalic.ttf',
#  '/usr/share/fonts/noto/NotoSansMalayalam-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerif-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansGujarati-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSerifHebrew-Black.ttf',
#  '/usr/share/fonts/noto/NotoSerifKhmer-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSerifThai-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansKaithi-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifTibetan-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansArmenian-Light.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-BoldItalic.otf',
#  '/usr/share/fonts/noto/NotoLoopedThaiUI-Light.ttf',
#  '/usr/share/fonts/noto/NotoSerifMalayalam-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansTeluguUI-Light.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansKR-Bold.otf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-Semibold.otf',
#  '/usr/share/fonts/noto/NotoSerif-Bold.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-BoldIt.otf',
#  '/usr/share/fonts/noto/NotoSansTirhuta-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-UltLt.otf',
#  '/usr/share/fonts/noto/NotoSansMalayalam-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansKhudawadi-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiExpandedExtraLight.ttf',
#  '/usr/share/fonts/noto/NotoSerifMyanmar-Light.ttf',
#  '/usr/share/fonts/TTF/courbd.ttf',
#  '/usr/share/fonts/OTF/FiraSans-Hair.otf',
#  '/usr/share/fonts/noto/NotoSerifEthiopic-Black.ttf',
#  '/usr/share/fonts/noto/NotoSerifTelugu-Black.ttf',
#  '/usr/share/fonts/TTF/DejaVuMathTeXGyre.ttf',
#  '/usr/share/fonts/TTF/FiraCode-Retina.ttf',
#  '/usr/share/fonts/noto/NotoSans-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansCoptic-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansOldSogdian-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifGeorgian-Black.ttf',
#  '/usr/share/fonts/droid/DroidSansHebrew-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansKhmer-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifOriya-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifBengali-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-SemiBold.otf',
#  '/usr/share/fonts/noto/NotoSansDevanagariUI-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansKhmerUI-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExpandedExtraBold.ttf',
#  '/usr/share/fonts/noto/NotoSans-Bold.ttf',
#  '/usr/share/fonts/TTF/TAMu_Kadampari.ttf',
#  '/usr/share/fonts/noto/NotoSerifTamil-Bold.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3VF-Roman.otf',
#  '/usr/share/fonts/OTF/Helvetica Neue/HelveticaNeue-Light.otf',
#  '/usr/share/fonts/noto/NotoSansPhoenician-Regular.ttf',
#  '/usr/share/fonts/droid/DroidSansTamil-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansHebrew-Black.ttf',
#  '/usr/share/fonts/noto/NotoLoopedThaiUI-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansTeluguUI-Thin.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraExpandedBold.ttf',
#  '/usr/share/fonts/noto/NotoSansArabicUI-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansTangsa-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansTaiTham-Bold.ttf',
#  '/usr/share/fonts/TTF/FiraCode-Light.ttf',
#  '/usr/share/fonts/TTF/OpenSans-SemiBold.ttf',
#  '/usr/share/fonts/noto/NotoSansSinhalaUI-Black.ttf',
#  '/usr/share/fonts/noto/NotoSerifLao-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansAdlamUnjoined-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansOriyaUI-Thin.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansJP-Medium.otf',
#  '/usr/share/fonts/gsfonts/Z003-MediumItalic.otf',
#  '/usr/share/fonts/OTF/FiraSans-SemiBoldItalic.otf',
#  '/usr/share/fonts/noto/NotoSansBengali-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansDevanagari-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansArmenian-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansPalmyrene-Regular.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-Medium.otf',
#  '/usr/share/fonts/noto/NotoSansTelugu-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansLao-Black.ttf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-HairItalic.otf',
#  '/usr/share/fonts/noto/NotoSerifThai-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansDevanagariUI-Thin.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue/HelveticaNeue-BoldItalic.otf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-BookItalic.otf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansMyanmar-Thin.ttf',
#  '/usr/share/fonts/gsfonts/NimbusRoman-Italic.otf',
#  '/usr/share/fonts/noto/NotoSansMalayalamUI-Black.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-Md.otf',
#  '/usr/share/fonts/noto/NotoSansVithkuqi-Regular.ttf',
#  '/usr/share/fonts/gsfonts/NimbusMonoPS-Bold.otf',
#  '/usr/share/fonts/noto/NotoSansSundanese-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansDevanagariUI-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSerifTamilSlanted-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansGlagolitic-Regular.ttf',
#  '/usr/share/fonts/gsfonts/NimbusMonoPS-Italic.otf',
#  '/usr/share/fonts/noto/NotoSansTamilUI-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifGeorgian-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansOsage-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansHatran-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraExpandedSemiBold.ttf',
#  '/usr/share/fonts/noto/NotoSansMarchen-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansArabic-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifTamilSlanted-Light.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiCondensedExtraBold.ttf',
#  '/usr/share/fonts/noto/NotoSansThaiUI-Black.ttf',
#  '/usr/share/fonts/noto/NotoTraditionalNushu-Bold.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-ExtraLight.otf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-Two.otf',
#  '/usr/share/fonts/noto/NotoSansOldSouthArabian-Regular.ttf',
#  '/usr/share/fonts/TTF/Verdanai.TTF',
#  '/usr/share/fonts/noto/NotoSerifBengali-Black.ttf',
#  '/usr/share/fonts/noto/NotoLoopedLaoUI-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansWarangCiti-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansMath-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansTamilUI-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansDevanagari-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSerifOriya-Medium.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-Hv.otf',
#  '/usr/share/fonts/noto/NotoSansMeeteiMayek-Black.ttf',
#  '/usr/share/fonts/noto/NotoSerifMyanmar-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansArabic-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansKannadaUI-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansLycian-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSans-LightItalic.otf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansKR-ExtraLight.otf',
#  '/usr/share/fonts/noto/NotoSansTaiTham-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifGurmukhi-Black.ttf',
#  '/usr/share/fonts/noto/NotoSerifTamilSlanted-Thin.ttf',
#  '/usr/share/fonts/noto/NotoLoopedLaoUI-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansJavanese-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-SemiBoldItalic.otf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraCondensedBold.ttf',
#  '/usr/share/fonts/TTF/DejaVuSans-BoldOblique.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-BlackIt.otf',
#  '/usr/share/fonts/noto/NotoSerifDivesAkuru-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansTeluguUI-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiCondensedExtraLight.ttf',
#  '/usr/share/fonts/noto/NotoSansBengaliUI-Regular.ttf',
#  '/usr/share/fonts/TTF/MuktiNarrowBold.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansJP-Heavy.otf',
#  '/usr/share/fonts/noto/NotoSerifDogra-Semibold.ttf',
#  '/usr/share/fonts/noto/NotoSansSyriac-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansLisu-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraExpandedExtraLight.ttf',
#  '/usr/share/fonts/noto/NotoSansGeorgian-Black.ttf',
#  '/usr/share/fonts/TTF/DejaVuSansCondensed-Oblique.ttf',
#  '/usr/share/fonts/noto/NotoSansTagbanwa-Regular.ttf',
#  '/usr/share/fonts/TTF/Pothana2000.ttf',
#  '/usr/share/fonts/noto/NotoSansKannada-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansSoraSompeng-Bold.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansKR-Light.otf',
#  '/usr/share/fonts/TTF/DejaVuSans-ExtraLight.ttf',
#  '/usr/share/fonts/TTF/NotoSansMono-Thin-Nerd-Font-Complete.ttf',
#  '/usr/share/fonts/noto/NotoSansKannadaUI-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansLaoUI-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraCondensedLight.ttf',
#  '/usr/share/fonts/noto/NotoSansDisplay-Medium.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue/HelveticaNeue-Medium.otf',
#  '/usr/share/fonts/gsfonts/URWGothic-BookOblique.otf',
#  '/usr/share/fonts/noto/NotoSansThai-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiExpandedLight.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiExpandedBlack.ttf',
#  '/usr/share/fonts/noto/NotoSansHanifiRohingya-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-HairItalic.otf',
#  '/usr/share/fonts/TTF/TSCu_Paranar.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-Hair.otf',
#  '/usr/share/fonts/OTF/Helvetica Neue/HelveticaNeue-CondensedBlack.otf',
#  '/usr/share/fonts/noto/NotoSerifToto-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSerifArmenian-Black.ttf',
#  '/usr/share/fonts/noto/NotoLoopedLao-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansIndicSiyaqNumbers-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansCyproMinoan-Regular.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-ExtraLightIt.otf',
#  '/usr/share/fonts/noto/NotoRashiHebrew-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansHebrew-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansCham-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-Expanded.ttf',
#  '/usr/share/fonts/noto/NotoLoopedLaoUI-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansAdlam-Bold.ttf',
#  '/usr/share/fonts/TTF/MesloLGS-NF-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansMedefaidrin-Medium.ttf',
#  '/usr/share/fonts/TTF/DejaVuSansCondensed-BoldOblique.ttf',
#  '/usr/share/fonts/TTF/Helvetica/Helvetica-Light.ttf',
#  '/usr/share/fonts/droid/DroidKufi-Bold.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-SemiBold.otf',
#  '/usr/share/fonts/noto/NotoSansCherokee-Medium.ttf',
#  '/usr/share/fonts/OTF/FiraSans-BookItalic.otf',
#  '/usr/share/fonts/TTF/Timesbd.TTF',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-LtEx.otf',
#  '/usr/share/fonts/noto/NotoSansMono-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansMongolian-Regular.ttf',
#  '/usr/share/fonts/TTF/TSCu_Times.ttf',
#  '/usr/share/fonts/noto/NotoSansHebrewNew-Bold.ttf',
#  '/usr/share/fonts/gsfonts/P052-Bold.otf',
#  '/usr/share/fonts/noto/NotoSans-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansHebrewNew-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSerifTibetan-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansGujaratiUI-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSans-ThinItalic.otf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-HvExO.otf',
#  '/usr/share/fonts/TTF/SagarNormal.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-CnO.otf',
#  '/usr/share/fonts/droid/DroidSansJapanese.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-Hair.otf',
#  '/usr/share/fonts/noto/NotoSerifMyanmar-Thin.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExpandedSemiBold.ttf',
#  '/usr/share/fonts/noto/NotoSansArabicUI-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansMyanmar-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraCondensedMedium.ttf',
#  '/usr/share/fonts/noto/NotoSerifDevanagari-Bold.ttf',
#  '/usr/share/fonts/noto/NotoTraditionalNushu-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansInscriptionalParthian-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraCondensedSemiBold.ttf',
#  '/usr/share/fonts/noto/NotoSansCherokee-Thin.ttf',
#  '/usr/share/fonts/TTF/cour.ttf',
#  '/usr/share/fonts/droid/DroidNaskh-Regular-SystemUI.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue/HelveticaNeue-UltraLight.otf',
#  '/usr/share/fonts/TTF/Ariali.TTF',
#  '/usr/share/fonts/noto/NotoSansNabataean-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansCham-Medium.ttf',
#  '/usr/share/fonts/liberation/LiberationMono-Bold.ttf',
#  '/usr/share/fonts/TTF/Helvetica/Helvetica-Oblique.ttf',
#  '/usr/share/fonts/noto/NotoSansBalinese-Bold.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-ExtraLight.otf',
#  '/usr/share/fonts/noto/NotoSansTangsa-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-BdOu.otf',
#  '/usr/share/fonts/noto/NotoSansElymaic-Regular.ttf',
#  '/usr/share/fonts/TTF/Hack-BoldItalic.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansGunjalaGondi-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansOlChiki-Regular.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-Bold.otf',
#  '/usr/share/fonts/TTF/AriBlk.TTF',
#  '/usr/share/fonts/noto/NotoSerifBengali-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansEthiopic-Medium.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-Four.otf',
#  '/usr/share/fonts/TTF/Inconsolata-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansCham-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansGurmukhiUI-Bold.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-UltLtEx.otf',
#  '/usr/share/fonts/noto/NotoRashiHebrew-Medium.ttf',
#  '/usr/share/fonts/TTF/DejaVuSerif-Italic.ttf',
#  '/usr/share/fonts/noto/NotoSansHebrewDroid-Medium.ttf',
#  '/usr/share/fonts/TTF/OpenSansCondensed-Light.ttf',
#  '/usr/share/fonts/TTF/Georgiai.TTF',
#  '/usr/share/fonts/noto/NotoSansBalinese-Regular.ttf',
#  '/usr/share/fonts/noto/NotoLoopedThai-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifGeorgian-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSerifVithkuqi-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifLao-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-Th.otf',
#  '/usr/share/fonts/noto/NotoSansMono-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-MdCn.otf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-Regular.otf',
#  '/usr/share/fonts/droid/DroidSansEthiopic-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansThaana-Black.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-ExtraBold.otf',
#  '/usr/share/fonts/noto/NotoSansMyanmarUI-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansHebrew-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansKhmerUI-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansTakri-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansGujaratiUI-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansThaiUI-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansZanabazarSquare-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansKannadaUI-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansSymbols-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifDogra-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansCham-Light.ttf',
#  '/usr/share/fonts/noto/NotoNaskhArabicUI-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansMedefaidrin-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansBuginese-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-LtCn.otf',
#  '/usr/share/fonts/noto/NotoSansBengaliUI-Black.ttf',
#  '/usr/share/fonts/noto/NotoSerifGurmukhi-Light.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-BoldItalic.otf',
#  '/usr/share/fonts/noto/NotoSansKayahLi-Bold.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-Bold.otf',
#  '/usr/share/fonts/gsfonts/URWBookman-LightItalic.otf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansJP-Normal.otf',
#  '/usr/share/fonts/noto/NotoSansSamaritan-Regular.ttf',
#  '/usr/share/fonts/noto/NotoLoopedThaiUI-Bold.ttf',
#  '/usr/share/fonts/OTF/FiraSans-UltraLight.otf',
#  '/usr/share/fonts/cantarell/Cantarell-VF.otf',
#  '/usr/share/fonts/noto/NotoSansMyanmar-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansLao-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansSharada-Regular.ttf',
#  '/usr/share/fonts/gsfonts/C059-Roman.otf',
#  '/usr/share/fonts/liberation/LiberationSans-Bold.ttf',
#  '/usr/share/fonts/TTF/oriya.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-BlkIt.otf',
#  '/usr/share/fonts/noto/NotoSansTifinaghAir-Regular.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-SemiboldIt.otf',
#  '/usr/share/fonts/noto/NotoSansGurmukhiUI-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansLimbu-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansArmenian-Black.ttf',
#  '/usr/share/fonts/gsfonts/StandardSymbolsPS.otf',
#  '/usr/share/fonts/noto/NotoSerifDevanagari-Thin.ttf',
#  '/usr/share/fonts/TTF/OpenSansCondensed-LightItalic.ttf',
#  '/usr/share/fonts/noto/NotoSans-BoldItalic.ttf',
#  '/usr/share/fonts/noto/NotoSansChakma-Regular.ttf',
#  '/usr/share/fonts/TTF/mal2-n.ttf',
#  '/usr/share/fonts/noto/NotoSerifTamilSlanted-Bold.ttf',
#  '/usr/share/fonts/TTF/akruti2.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-Light.otf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-ExtraLightIt.otf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-Bold.otf',
#  '/usr/share/fonts/TTF/NotoSansMono-Black-Nerd-Font-Complete.ttf',
#  '/usr/share/fonts/noto/NotoSerifBalinese-Regular.ttf',
#  '/usr/share/fonts/TTF/Comicbd.TTF',
#  '/usr/share/fonts/TTF/Inconsolata-CondensedExtraLight.ttf',
#  '/usr/share/fonts/liberation/LiberationMono-BoldItalic.ttf',
#  '/usr/share/fonts/TTF/Arialbi.TTF',
#  '/usr/share/fonts/TTF/Hack-Italic.ttf',
#  '/usr/share/fonts/noto/NotoSansBassaVah-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifVithkuqi-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansMyanmarUI-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansVithkuqi-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansMalayalamUI-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansGunjalaGondi-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansSoraSompeng-Medium.ttf',
#  '/usr/share/fonts/TTF/GurbaniBoliLite.ttf',
#  '/usr/share/fonts/liberation/LiberationSans-Regular.ttf',
#  '/usr/share/fonts/TTF/Georgia.TTF',
#  '/usr/share/fonts/noto/NotoSansMeeteiMayek-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansTelugu-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansThai-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSans-Regular.ttf',
#  '/usr/share/fonts/noto/NotoLoopedThai-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansKhmerUI-Medium.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-Ex.otf',
#  '/usr/share/fonts/TTF/DejaVuSans.ttf',
#  '/usr/share/fonts/noto/NotoSansThai-Light.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-CondensedLight.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraExpanded.ttf',
#  '/usr/share/fonts/noto/NotoSerifTelugu-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansBengaliUI-Light.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-ThIt.otf',
#  '/usr/share/fonts/noto/NotoSansThaana-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansLaoUI-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansKhmerUI-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansGeorgian-Medium.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-CondensedBold.ttf',
#  '/usr/share/fonts/noto/NotoSansBamum-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansOlChiki-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansHanifiRohingya-Medium.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-Regular.otf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-Bold.otf',
#  '/usr/share/fonts/noto/NotoSansThaana-Medium.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-Bold.ttf',
#  '/usr/share/fonts/TTF/Helvetica/Helvetica-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifBengali-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifSinhala-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansLaoUI-Light.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3VF-Italic.otf',
#  '/usr/share/fonts/noto/NotoSansDisplay-LightItalic.ttf',
#  '/usr/share/fonts/noto/NotoSansKhmer-Black.ttf',
#  '/usr/share/fonts/gsfonts/NimbusMonoPS-BoldItalic.otf',
#  '/usr/share/fonts/noto/NotoSansSinhala-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansCuneiform-Regular.ttf',
#  '/usr/share/fonts/TTF/Timesi.TTF',
#  '/usr/share/fonts/noto/NotoSansOldTurkic-Regular.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansJP-Light.otf',
#  '/usr/share/fonts/noto/NotoSerifThai-Thin.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue/HelveticaNeue-UltraLightItalic.otf',
#  '/usr/share/fonts/noto/NotoSansImperialAramaic-Regular.ttf',
#  '/usr/share/fonts/liberation/LiberationSerif-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifThai-Regular.ttf',
#  '/usr/share/fonts/TTF/courbi.ttf',
#  '/usr/share/fonts/TTF/Arial.TTF',
#  '/usr/share/fonts/noto/NotoSansTelugu-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansGurmukhi-Thin.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-Condensed.ttf',
#  '/usr/share/fonts/noto/NotoSansMalayalamUI-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSerifKhmer-Black.ttf',
#  '/usr/share/fonts/noto/NotoSerifGujarati-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansHebrewDroid-Regular.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansCN-Regular.otf',
#  '/usr/share/fonts/noto/NotoSerifTamil-Thin.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-BdExO.otf',
#  '/usr/share/fonts/droid/DroidNaskh-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansDevanagari-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifGurmukhi-Medium.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansJP-Bold.otf',
#  '/usr/share/fonts/TTF/Georgiab.TTF',
#  '/usr/share/fonts/OTF/FiraSansCompressed-MediumItalic.otf',
#  '/usr/share/fonts/noto/NotoSansGeorgian-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansNandinagari-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiCondensed.ttf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-BlackItalic.ttf',
#  '/usr/share/fonts/noto/NotoSerifTamil-Medium.ttf',
#  '/usr/share/fonts/TTF/Timesbi.TTF',
#  '/usr/share/fonts/noto/NotoLoopedLaoUI-Medium.ttf',
#  '/usr/share/fonts/TTF/couri.ttf',
#  '/usr/share/fonts/noto/NotoSansSinhalaUI-Light.ttf',
#  '/usr/share/fonts/liberation/LiberationSerif-BoldItalic.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraExpandedLight.ttf',
#  '/usr/share/fonts/noto/NotoSansOlChiki-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansEthiopic-Thin.ttf',
#  '/usr/share/fonts/noto/NotoLoopedThai-Light.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-Semibold.otf',
#  '/usr/share/fonts/TTF/TSCu_paranarb.ttf',
#  '/usr/share/fonts/noto/NotoSansCanadianAboriginal-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansMyanmarUI-Light.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-HeavyItalic.otf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-Light.otf',
#  '/usr/share/fonts/noto/NotoSansCham-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansGrantha-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansThaana-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansNushu-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-MdCnO.otf',
#  '/usr/share/fonts/noto/NotoSerifKannada-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansMultani-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiCondensedBlack.ttf',
#  '/usr/share/fonts/noto/NotoSansArmenian-Regular.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-BoldIt.otf',
#  '/usr/share/fonts/TTF/NotoSansMono-Regular-Nerd-Font-Complete.ttf',
#  '/usr/share/fonts/noto/NotoSerifHebrew-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansTelugu-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-Light.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-LtIt.otf',
#  '/usr/share/fonts/noto/NotoSerifOriya-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansMeeteiMayek-Medium.ttf',
#  '/usr/share/fonts/TTF/DejaVuSansMono-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansDeseret-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansDisplay-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansDevanagari-Light.ttf',
#  '/usr/share/fonts/TTF/OpenSans-BoldItalic.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-UltLtExO.otf',
#  '/usr/share/fonts/TTF/TSCu_Comic.ttf',
#  '/usr/share/fonts/noto/NotoSansModi-Regular.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodeVariable-Roman.otf',
#  '/usr/share/fonts/noto/NotoSerifVithkuqi-Medium.ttf',
#  '/usr/share/fonts/gsfonts/URWGothic-Book.otf',
#  '/usr/share/fonts/noto/NotoSansHebrewNew-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansNewa-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansMasaramGondi-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifSinhala-Light.ttf',
#  '/usr/share/fonts/noto/NotoSans-Italic.ttf',
#  '/usr/share/fonts/OTF/FiraSans-Bold.otf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-Blk.otf',
#  '/usr/share/fonts/TTF/MalOtf.ttf',
#  '/usr/share/fonts/OTF/FiraSans-Heavy.otf',
#  '/usr/share/fonts/noto/NotoSansLao-Light.ttf',
#  '/usr/share/fonts/gsfonts/NimbusSans-Regular.otf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-SemiBoldItalic.otf',
#  '/usr/share/fonts/gsfonts/C059-BdIta.otf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-Medium.otf',
#  '/usr/share/fonts/noto/NotoLoopedThai-Black.ttf',
#  '/usr/share/fonts/OTF/FiraMono-Regular.otf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraLight.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-MediumIt.otf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-LightItalic.otf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansKannadaUI-Light.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-ThinItalic.otf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-EightItalic.otf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-BlkEx.otf',
#  '/usr/share/fonts/noto/NotoSansCherokee-Light.ttf',
#  '/usr/share/fonts/OTF/FiraSans-Thin.otf',
#  '/usr/share/fonts/noto/NotoSansShavian-Regular.ttf',
#  '/usr/share/fonts/TTF/TSCu_paranari.ttf',
#  '/usr/share/fonts/noto/NotoSansAdlam-Regular.ttf',
#  '/usr/share/fonts/liberation/LiberationSans-BoldItalic.ttf',
#  '/usr/share/fonts/noto/NotoSerifGujarati-Thin.ttf',
#  '/usr/share/fonts/TTF/OpenSans-ExtraBoldItalic.ttf',
#  '/usr/share/fonts/noto/NotoSerifHebrew-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansGothic-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-XBlkCnO.otf',
#  '/usr/share/fonts/TTF/OpenSans-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansKannada-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSans-MediumItalic.ttf',
#  '/usr/share/fonts/noto/NotoNaskhArabicUI-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiExpanded.ttf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-MediumItalic.ttf',
#  '/usr/share/fonts/noto/NotoSansSyriac-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansTifinaghAhaggar-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerif-Black.ttf',
#  '/usr/share/fonts/TTF/DejaVuSansMono.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-BdCn.otf',
#  '/usr/share/fonts/droid/DroidNaskh-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraCondensedExtraLight.ttf',
#  '/usr/share/fonts/noto/NotoSansTaiTham-Medium.ttf',
#  '/usr/share/fonts/droid/DroidSans-Bold.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-EightItalic.otf',
#  '/usr/share/fonts/TTF/mal1-n.ttf',
#  '/usr/share/fonts/droid/DroidSansFallbackFull.ttf',
#  '/usr/share/fonts/noto/NotoRashiHebrew-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansArmenian-Thin.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-It.otf',
#  '/usr/share/fonts/noto/NotoSansGeorgian-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-ThEx.otf',
#  '/usr/share/fonts/OTF/FiraSans-ExtraBoldItalic.otf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-ExtraLightItalic.otf',
#  '/usr/share/fonts/noto/NotoSansThaiUI-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifBengali-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansKhojki-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansPauCinHau-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-HvCn.otf',
#  '/usr/share/fonts/noto/NotoSansCanadianAboriginal-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSerifGeorgian-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerif-Thin.ttf',
#  '/usr/share/fonts/TTF/MesloLGS-NF-Bold.ttf',
#  '/usr/share/fonts/noto/NotoKufiArabic-Black.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansCN-Light.otf',
#  '/usr/share/fonts/noto/NotoSansMalayalam-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansTamil-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansKannadaUI-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansDisplay-Light.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraCondensed.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-HvCnO.otf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-Regular.otf',
#  '/usr/share/fonts/noto/NotoSansCarian-Regular.ttf',
#  '/usr/share/fonts/TTF/akruti1b.ttf',
#  '/usr/share/fonts/noto/NotoLoopedThaiUI-Regular.ttf',
#  '/usr/share/fonts/noto/NotoRashiHebrew-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansGujarati-Light.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraExpandedExtraLight.ttf',
#  '/usr/share/fonts/noto/NotoSansLinearB-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraCondensedBlack.ttf',
#  '/usr/share/fonts/noto/NotoNaskhArabic-Regular.ttf',
#  '/usr/share/fonts/TTF/Arialbd.TTF',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-It.otf',
#  '/usr/share/fonts/noto/NotoSansMandaic-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSans-Black.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraCondensedExtraLight.ttf',
#  '/usr/share/fonts/OTF/FiraSans-ExtraLightItalic.otf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-Regular.otf',
#  '/usr/share/fonts/noto/NotoSansDisplay-Black.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExpandedBold.ttf',
#  '/usr/share/fonts/noto/NotoRashiHebrew-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansSinhalaUI-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansMeeteiMayek-Bold.ttf',
#  '/usr/share/fonts/TTF/Sampige.ttf',
#  '/usr/share/fonts/noto/NotoSansKannada-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansGujaratiUI-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansBhaiksuki-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifGrantha-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansKhmerUI-Light.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraBold.ttf',
#  '/usr/share/fonts/droid/DroidSansFallbackLegacy.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraCondensedLight.ttf',
#  '/usr/share/fonts/noto/NotoSansBengali-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansHanifiRohingya-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifArmenian-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraExpandedLight.ttf',
#  '/usr/share/fonts/noto/NotoSansArabicUI-Medium.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-Light.otf',
#  '/usr/share/fonts/noto/NotoSerif-ThinItalic.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue/HelveticaNeue.otf',
#  '/usr/share/fonts/noto/NotoSerifThai-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansKannada-Medium.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-Roman.otf',
#  '/usr/share/fonts/gsfonts/NimbusRoman-Bold.otf',
#  '/usr/share/fonts/noto/NotoSerifDogra-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiExpandedExtraBold.ttf',
#  '/usr/share/fonts/droid/DroidSansHebrew-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifTamil-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansInscriptionalPahlavi-Regular.ttf',
#  '/usr/share/fonts/TTF/Hack-Bold.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-MediumItalic.otf',
#  '/usr/share/fonts/gsfonts/NimbusSansNarrow-Regular.otf',
#  '/usr/share/fonts/noto/NotoSansYi-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansBengali-Thin.ttf',
#  '/usr/share/fonts/noto/NotoLoopedLao-Light.ttf',
#  '/usr/share/fonts/droid/DroidSerif-Regular.ttf',
#  '/usr/share/fonts/gsfonts/C059-Italic.otf',
#  '/usr/share/fonts/noto/NotoSansLao-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansSinhala-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExpandedExtraLight.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraCondensedExtraBold.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-Bd.otf',
#  '/usr/share/fonts/noto/NotoSansRunic-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansBrahmi-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifEthiopic-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansDevanagariUI-Bold.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansCN-Bold.otf',
#  '/usr/share/fonts/noto/NotoSansCherokee-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansArabic-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansPhagsPa-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifEthiopic-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansEthiopic-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansSoraSompeng-Regular.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-LightIt.otf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiCondensedSemiBold.ttf',
#  '/usr/share/fonts/TTF/OpenSans-Italic.ttf',
#  '/usr/share/fonts/TTF/malayalam.ttf',
#  '/usr/share/fonts/OTF/FiraSans-UltraItalic.otf',
#  '/usr/share/fonts/adobe-source-sans/SourceSans3-Black.otf',
#  '/usr/share/fonts/noto/NotoSansOriyaUI-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraExpandedSemiBold.ttf',
#  '/usr/share/fonts/noto/NotoSansSinhalaUI-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSerifSinhala-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSerif-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-Light.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue/HelveticaNeue-LightItalic.otf',
#  '/usr/share/fonts/noto/NotoSansArmenian-Bold.ttf',
#  '/usr/share/fonts/TTF/MesloLGS-NF-Italic.ttf',
#  '/usr/share/fonts/OTF/FiraSans-Italic.otf',
#  '/usr/share/fonts/noto/NotoSansBengaliUI-Bold.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-UltraLightItalic.otf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-UltLtCn.otf',
#  '/usr/share/fonts/noto/NotoSansGurmukhi-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansOriyaUI-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansGeorgian-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansLaoUI-Medium.ttf',
#  '/usr/share/fonts/TTF/OpenSans-Light.ttf',
#  '/usr/share/fonts/noto/NotoSerifHebrew-Medium.ttf',
#  '/usr/share/fonts/TTF/DejaVuSansMono-Oblique.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-Eight.otf',
#  '/usr/share/fonts/TTF/trebucit.ttf',
#  '/usr/share/fonts/noto/NotoSansMono-Bold.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-HeavyItalic.otf',
#  '/usr/share/fonts/noto/NotoSansArabicUI-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSans-FourItalic.otf',
#  '/usr/share/fonts/noto/NotoTraditionalNushu-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSans-Four.otf',
#  '/usr/share/fonts/gsfonts/NimbusRoman-BoldItalic.otf',
#  '/usr/share/fonts/noto/NotoSansBalinese-Medium.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-Two.otf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-Light.otf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraCondensedExtraBold.ttf',
#  '/usr/share/fonts/noto/NotoSansOriyaUI-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraExpandedBlack.ttf',
#  '/usr/share/fonts/noto/NotoSansArabicUI-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansGurmukhiUI-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansTeluguUI-Bold.ttf',
#  '/usr/share/fonts/TTF/akruti2b.ttf',
#  '/usr/share/fonts/noto/NotoKufiArabic-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-BdIt.otf',
#  '/usr/share/fonts/noto/NotoSansEthiopic-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansMalayalamUI-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansDisplay-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSerifEthiopic-Medium.ttf',
#  '/usr/share/fonts/adobe-source-han-sans/SourceHanSansCN-Medium.otf',
#  '/usr/share/fonts/liberation/LiberationSans-Italic.ttf',
#  '/usr/share/fonts/noto/NotoSansRejang-Regular.ttf',
#  '/usr/share/fonts/TTF/TAMu_Kalyani.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-FourItalic.otf',
#  '/usr/share/fonts/noto/NotoSansMalayalam-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansSinhala-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansTangsa-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansBamum-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansLaoUI-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifGeorgian-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansSinhala-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansGurmukhiUI-Medium.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-TwoItalic.otf',
#  '/usr/share/fonts/TTF/OpenSans-LightItalic.ttf',
#  '/usr/share/fonts/droid/DroidSansDevanagari-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraExpanded.ttf',
#  '/usr/share/fonts/noto/NotoSansKhmerUI-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifKhojki-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansHebrewNew-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansKhmer-Light.ttf',
#  '/usr/share/fonts/TTF/DejaVuSans-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansDisplay-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSans-UltraLightItalic.otf',
#  '/usr/share/fonts/TTF/Inconsolata-CondensedMedium.ttf',
#  '/usr/share/fonts/TTF/Gargi-1.2b.ttf',
#  '/usr/share/fonts/noto/NotoSansGujaratiUI-Black.ttf',
#  '/usr/share/fonts/noto/NotoSansSundanese-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansMalayalam-Light.ttf',
#  '/usr/share/fonts/noto/NotoSerifTibetan-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSerifArmenian-Light.ttf',
#  '/usr/share/fonts/noto/NotoSerifTamil-Light.ttf',
#  '/usr/share/fonts/noto/NotoSerifTelugu-Light.ttf',
#  '/usr/share/fonts/noto/NotoSerifMalayalam-Light.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiCondensedMedium.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodeVariable-Italic.otf',
#  '/usr/share/fonts/OTF/FiraSans-SemiBold.otf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-ExtraLight.otf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiBold.ttf',
#  '/usr/share/fonts/noto/NotoSansTifinaghGhat-Regular.ttf',
#  '/usr/share/fonts/TTF/DejaVuSerifCondensed-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSans-Medium.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-ThinItalic.otf',
#  '/usr/share/fonts/noto/NotoSerifTibetan-Bold.ttf',
#  '/usr/share/fonts/TTF/Hack-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansTifinaghRhissaIxa-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansCanadianAboriginal-Black.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-ThCn.otf',
#  '/usr/share/fonts/noto/NotoSansMyanmar-Light.ttf',
#  '/usr/share/fonts/TTF/OpenSans-Regular.ttf',
#  '/usr/share/fonts/TTF/padmaa-Bold-0.5.ttf',
#  '/usr/share/fonts/TTF/DejaVuSansCondensed.ttf',
#  '/usr/share/fonts/noto/NotoSansSyriac-Thin.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-SemiCondensedLight.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue/HelveticaNeue-Italic.otf',
#  '/usr/share/fonts/noto/NotoSansGunjalaGondi-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansMalayalam-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansTifinagh-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-FourItalic.otf',
#  '/usr/share/fonts/noto/NotoSerifLao-Black.ttf',
#  '/usr/share/fonts/noto/NotoSerifKannada-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraExpandedBlack.ttf',
#  '/usr/share/fonts/noto/NotoSansThaana-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansSymbols2-Regular.ttf',
#  '/usr/share/fonts/TTF/LikhanNormal.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSerifKannada-Regular.ttf',
#  '/usr/share/fonts/TTF/DejaVuSerif-BoldItalic.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-UltLtIt.otf',
#  '/usr/share/fonts/noto/NotoSansMyanmar-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansMalayalamUI-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansTelugu-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansSogdian-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerif-LightItalic.ttf',
#  '/usr/share/fonts/noto/NotoSansOsmanya-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansNewTaiLue-Regular.ttf',
#  '/usr/share/fonts/TTF/MuktiNarrow.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue/HelveticaNeue-Bold.otf',
#  '/usr/share/fonts/noto/NotoSansTagalog-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-ExtraBoldItalic.otf',
#  '/usr/share/fonts/TTF/DejaVuSerifCondensed.ttf',
#  '/usr/share/fonts/TTF/Times.TTF',
#  '/usr/share/fonts/noto/NotoSans-BlackItalic.ttf',
#  '/usr/share/fonts/TTF/gbolilite.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-Heavy.otf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-SemiboldIt.otf',
#  '/usr/share/fonts/OTF/FiraSans-Two.otf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-Cn.otf',
#  '/usr/share/fonts/noto/NotoSerifGurmukhi-Bold.ttf',
#  '/usr/share/fonts/gsfonts/P052-Roman.otf',
#  '/usr/share/fonts/gsfonts/NimbusSans-Bold.otf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-It.otf',
#  '/usr/share/fonts/noto/NotoSansMeroitic-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifDisplay-Thin.ttf',
#  '/usr/share/fonts/TTF/akruti1.ttf',
#  '/usr/share/fonts/noto/NotoSansKannada-Thin.ttf',
#  '/usr/share/fonts/gsfonts/NimbusMonoPS-Regular.otf',
#  '/usr/share/fonts/noto/NotoSansKhmer-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansGurmukhi-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansGujarati-Regular.ttf',
#  '/usr/share/fonts/noto/NotoNastaliqUrdu-Bold.ttf',
#  '/usr/share/fonts/droid/DroidKufi-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSerifYezidi-Medium.ttf',
#  '/usr/share/fonts/adobe-source-sans/SourceSansPro-Regular.otf',
#  '/usr/share/fonts/OTF/FiraMono-Medium.otf',
#  '/usr/share/fonts/noto/NotoSansSymbols-Regular.ttf',
#  '/usr/share/fonts/TTF/DejaVuSerif.ttf',
#  '/usr/share/fonts/noto/NotoSansKharoshthi-Regular.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-MdEx.otf',
#  '/usr/share/fonts/noto/NotoSansDisplay-BlackItalic.ttf',
#  '/usr/share/fonts/OTF/FiraSans-Medium.otf',
#  '/usr/share/fonts/noto/NotoSerif-Light.ttf',
#  '/usr/share/fonts/noto/NotoSansGujarati-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansSaurashtra-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExpandedMedium.ttf',
#  '/usr/share/fonts/droid/DroidSans.ttf',
#  '/usr/share/fonts/noto/NotoSerifYezidi-Regular.ttf',
#  '/usr/share/fonts/adobe-source-code-pro/SourceCodePro-Light.otf',
#  '/usr/share/fonts/noto/NotoSansMendeKikakui-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansCypriot-Regular.ttf',
#  '/usr/share/fonts/noto/NotoLoopedLao-Medium.ttf',
#  '/usr/share/fonts/noto/NotoSansBamum-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansMro-Regular.ttf',
#  '/usr/share/fonts/noto/NotoSansMeeteiMayek-Light.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-Bold.otf',
#  '/usr/share/fonts/noto/NotoSansDisplay-ThinItalic.ttf',
#  '/usr/share/fonts/noto/NotoSerifKannada-Light.ttf',
#  '/usr/share/fonts/OTF/FiraSansCompressed-BookItalic.otf',
#  '/usr/share/fonts/TTF/DejaVuSansCondensed-Bold.ttf',
#  '/usr/share/fonts/OTF/PowerlineSymbols.otf',
#  '/usr/share/fonts/noto/NotoSerifArmenian-Medium.ttf',
#  '/usr/share/fonts/OTF/Helvetica Neue LT Std/HelveticaNeueLTStd-HvIt.otf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraCondensedBold.ttf',
#  '/usr/share/fonts/noto/NotoSansTaiViet-Regular.ttf',
#  '/usr/share/fonts/OTF/FiraSans-HeavyItalic.otf',
#  '/usr/share/fonts/TTF/Inconsolata-ExtraExpandedBold.ttf',
#  '/usr/share/fonts/noto/NotoSansHebrew-Bold.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-UltraCondensedMedium.ttf',
#  '/usr/share/fonts/noto/NotoSansMeeteiMayek-Thin.ttf',
#  '/usr/share/fonts/noto/NotoSansCanadianAboriginal-Thin.ttf',
#  '/usr/share/fonts/TTF/DejaVuSerifCondensed-BoldItalic.ttf',
#  '/usr/share/fonts/OTF/FiraSansCondensed-Thin.otf',
#  '/usr/share/fonts/gsfonts/NimbusSans-Italic.otf',
#  '/usr/share/fonts/noto/NotoMusic-Regular.ttf',
#  '/usr/share/fonts/TTF/Inconsolata-ExpandedLight.ttf',
#  '/usr/share/fonts/OTF/FiraSans-MediumItalic.otf',
#  '/usr/share/fonts/noto/NotoNaskhArabic-Medium.ttf',
#  '/usr/share/fonts/TTF/Helvetica/Helvetica-BoldOblique.ttf',
#  '/usr/share/fonts/noto/NotoSansTifinaghSIL-Regular.ttf',
#  '/usr/share/fonts/noto/NotoNaskhArabic-Bold.ttf',
#  '/usr/share/fonts/noto/NotoSansBuhid-Regular.ttf',
#  ...]

# %%
plt.plot(1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
video = pims.Cine('/home/fvega/tesla/thin_layer/kovacs/041022_150Hz_density0.5_step_down_62.5_25.cine')

# %%
# !ffplay '/home/fvega/tesla/thin_layer/kovacs/041022_150Hz_density0.5_step_down_62.5_25.cine'
# Out:
# ffplay version n5.1.2 Copyright (c) 2003-2022 the FFmpeg developers
#   built with gcc 12.2.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, cine, from '/home/fvega/tesla/thin_layer/kovacs/041022_150Hz_density0.5_step_down_62.5_25.cine':
#   Duration: 00:00:38.42, start: 0.000000, bitrate: 6656290 kb/s
#   Stream #0:0: Video: rawvideo (BIT[0] / 0x544942), gray16le, 832x800, 1k tbr, 1k tbn
#     Metadata:
#       camera_version  : 7004
#       firmware_version: 21870
#       software_version: 800
#       recording_timezone: -7200
#       brightness      : 0
#       contrast        : 0
#       gamma           : 34
#       wbgain[0].r     : 1.172500
#       wbgain[0].b     : 2.200420
#       shutter_ns      : 150000
#       enable_crop     : 0
#       crop_left       : -224
#       crop_top        : 0
#       crop_right      : -224
#       crop_bottom     : 0
#    1.95 M-V:  1.867 fd=   6 aq=    0KB vq=    0KB sq=    0B f=0/0

# %%
video[0]
# Out:
# Frame([[194, 196, 193, ..., 155, 162, 156],
#        [207, 214, 205, ..., 141, 153, 144],
#        [220, 214, 214, ..., 153, 154, 162],
#        ...,
#        [155, 152, 154, ..., 263, 268, 266],
#        [154, 149, 156, ..., 257, 257, 252],
#        [154, 160, 145, ..., 243, 246, 244]], dtype=uint16)

# %%
video.image_count
# Out:
# 38419

# %%
datos = pd.read_pickle('/home/fvega/Datos/thin_layer/linked_150Hz_densidad0.5_stepdown_62.5_25.pkl')
datos.head()
# Out:
#                x           y  frame  particle
# 0     421.738534   16.711356      0         0
# 3818  133.182416  511.339173      0         1
# 3817  688.691642  509.790729      0         2
# 3816  530.393817  510.115225      0         3
# 3815  439.205483  509.574385      0         4

# %%
datos = pd.read_pickle('/home/fvega/Datos/thin_layer/linked_180Hz_densidad0.5_stepdown_62.5_25.pkl')
datos.head()
# Out:
#                x           y  frame  particle
# 0     446.809849   17.903212      0         0
# 3788  164.591026  510.689960      0         1
# 3787  557.198706  510.038409      0         2
# 3786  545.167494  510.287434      0         3
# 3785  472.308948  509.634331      0         4

# %%
# change column names
datos.rename(columns ={'x':'x', 'y':'y', 'frame':'frame', 'particle':'track'}, inplace=True)
# reorder so that vels can be calculated
# reset disordered index
datos = datos.sort_values(by=['track','frame']).reset_index(drop=True)
#datos = datos[datos.frame<10000]
#datos  = datos[int(len(datos)*0.40):int(len(datos)*0.60)
# print new 
datos.head()
# Out:
#             x          y  frame  track
# 0  421.738534  16.711356      0      0
# 1  421.777416  16.687892      1      0
# 2  421.314530  16.432831      2      0
# 3  421.215059  16.428409      3      0
# 4  421.168563  16.609974      4      0

# %%
# get velocities from track-frame ordered table
#datos = datos[:-1] # delete last state (it has no vel)
# save velocities to table
vx = np.diff(datos.x.values)
vy = np.diff(datos.y.values)
datos = datos[:-1]
datos['vx'] = vx.tolist()
datos['vy'] = vy.tolist()
del vx, vy
gc.collect()
datos.head()

# %%
#reorder by time so that temp. evolution can be easily stored
datos = datos.sort_values(by=['frame','track'])
datos.head()
Nframes = np.max(datos.frame.values) # no. of frames
# keep only each Deltat alternate states
Deltat = 20
datos = datos[datos['frame'].isin(np.arange(0,Nframes,Deltat))]
datos.head()

# %%
# build the particle kinetic energy lists for each time that was kept
timelist = np.unique(datos.frame.values)
nt = int(len(timelist))-1
v2list = [[] for i in range(nt)]
for t in range(nt):
    v2list[t] = datos[datos.frame==timelist[t]].vx.values**2 + datos[datos.frame==timelist[t]].vy.values**2
    if t%10==0:
        printp('t= ' + str(t) + ' of ' + str(nt))
# Out:
# t= 1910 of 1919

# %%
v2 = np.zeros(nt)
for t in range(nt-1):
    v2list[t] = v2list[t][v2list[t]<0.8]
    v2[t] = np.mean(v2list[t])
    if t%10==0:
        printp('t= ' + str(t) + ' of ' + str(nt))
# Out:
# t= 1910 of 1919

# %% [markdown]
# # Plots for Frequency 150 Hz

# %% [markdown]
# ### Plots for kinetic energy lists at given times

# %%
# initial stage
plt.figure(1)
plt.xlabel(r'$\mathrm{track~no.} (i)$')
plt.ylabel(r'$v_i^2$')
plt.title('initial stage')
plt.plot(v2list[10],'.', color='b', markersize=3)
plt.savefig('initial_stage_150Hz.eps',bbox_inches='tight')

# %%
plt.close(1)

# %%
# initial stage
plt.figure(2)
plt.xlabel(r'$\mathrm{track~no.} (i)$')
plt.ylabel(r'$v_i^2$')
plt.title('final stage')
plt.plot(v2list[-10],'.', color='b', markersize=3)
plt.savefig('final_stage_150Hz.eps',bbox_inches='tight')

# %%
plt.close(2)

# %%
# !gv v2t_150Hz.eps
# Out:
# Warning: Cannot convert string "-*-Helvetica-Medium-R-Normal--*-140-*-*-P-*-ISO8859-1" to type FontStruct
# Warning: Missing charsets in String to FontSet conversion
# Warning: Cannot convert string "-*-Helvetica-Medium-R-Normal--*-120-*-*-P-*-ISO8859-1" to type FontStruct
# Warning: Cannot convert string "-*-Helvetica-Medium-R-Normal--*-100-*-*-P-*-ISO8859-1" to type FontStruct
# Warning: Cannot convert string "-*-Helvetica-Bold-R-Normal--*-120-*-*-P-*-ISO8859-1" to type FontStruct

# %%
# time trajectory of v2 average
plt.figure(3)
plt.xlabel(r'$\mathrm{frame~no.}}$')
plt.ylabel(r'$\langle v^2\rangle$')
plt.plot(v2[:-10],'.',c='b', markersize=3)
plt.savefig('v2t_150Hz.eps', bbox_inches='tight')

# %%
plt.close(3)

# %% [markdown]
# # Plots for Frequency 180 Hz

# %% [markdown]
# ### Plots for kinetic energy lists at given times

# %%
# Initial stage
plt.figure(4)
plt.xlabel(r'$\mathrm{frame~no.}}$')
plt.ylabel(r'$\langle v^2\rangle$')
plt.plot(v2list[10],'.',color='r',markersize=3)
plt.savefig('initial_stage_180Hz.eps', bbox_inches='tight')

# %%
plt.close(4)

# %%
# final stage
plt.figure(5)
plt.xlabel(r'$\mathrm{frame~no.}}$')
plt.ylabel(r'$\langle v^2\rangle$')
plt.plot(v2list[-10], '.', color='r',markersize=3)
plt.savefig('final_stage_180Hz.eps', bbox_inches='tight')

# %%
plt.close(5)

# %%
# time trajectory of v2 average
plt.figure(6)
plt.xlabel(r'$\mathrm{frame~no.}}$')
plt.ylabel(r'$\langle v^2\rangle$')
plt.plot(v2[:-10],'.',c='r', markersize=3)
plt.savefig('v2t_180Hz.eps', bbox_inches='tight')

# %%
plt.close(6)

# %%
# !gv v2t_180Hz.eps
# Out:
# Warning: Cannot convert string "-*-Helvetica-Medium-R-Normal--*-140-*-*-P-*-ISO8859-1" to type FontStruct
# Warning: Missing charsets in String to FontSet conversion
# Warning: Cannot convert string "-*-Helvetica-Medium-R-Normal--*-120-*-*-P-*-ISO8859-1" to type FontStruct
# Warning: Cannot convert string "-*-Helvetica-Medium-R-Normal--*-100-*-*-P-*-ISO8859-1" to type FontStruct
# Warning: Cannot convert string "-*-Helvetica-Bold-R-Normal--*-120-*-*-P-*-ISO8859-1" to type FontStruct

# %%
plt.close(6)

# %%
plt.figure()
plt.plot(v2[tmin:tmax-1],'.')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.plot(v2[tmin:tmax-1],'.')

# %%
plt.plot(v2[tmin+100:tmin+120],'.')

# %%
import gc
del(datos)
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [37], line 2
#       1 import gc
# ----> 2 del(datos)
#       3 gc.collect()
#
# NameError: name 'datos' is not defined

# %%
t=100
if t%51:
    print('hola\n')
# Out:
# hola

# %%
datos[datos.frame==tmin+2].vx.values**2 + datos[datos.frame==tmin+2].vx.values**2
# Out:
# array([2.34122180e-02, 3.31882742e-02, 2.55571862e-01, ...,
#        7.38158457e+04, 1.56493307e-02, 1.29635982e-02])

# %%
np.select(v2list[tmin]

# %%
x = np.arange(6)
condlist = [x<5,x>3]
choicelist = [x, x]

np.select(condlist, choicelist, 42)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
v2list[tmin][v2list[tmin]<1]
# Out:
# array([3.64090181e-03, 2.59969338e-03, 5.90772819e-03, ...,
#        7.31394817e-01, 2.65928328e-04, 4.01622794e-01])
